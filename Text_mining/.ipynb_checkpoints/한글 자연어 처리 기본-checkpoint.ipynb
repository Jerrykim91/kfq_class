# %% [markdown]
# ### 꼬꼬마 형태소 분석기 사용
#
# - 가상환경은 base로 구성
# - 향후 프로젝트때 세팅에 시간이 많이 소요되는 부분은 고려하여 base로 구성

# %%
# 1. 형태소 모듈 가져오기
from konlpy.tag import Kkma

# %%
# 2. 형태소 객체 생성
kkma = Kkma()

# %%
# 3. 문장 <- 재료(텍스트)
test_text = '''
일본이 한국을 백색국가(수출 심사 우대국)에서 제외하는 수출무역관리령
개정안 시행일이 열흘도 채 남지 않았다 정부는 자율준수프로그램(ICP) 
인증을 받은 일본 기업을 통하면 지금처럼 수입에 큰 어려움이 없을 것이라는 입장이다 
다만 어떤 기업이 여기에 해당하는지 전체 명단의 절반도 
파악하지 못했다는 점은 우려스럽다

19일 전략물자관리원과 코트라 등에 따르면 일본 
내 ICP 인증 기업은 1300여곳으로 추정된다 이 가운데 사명을 공개한 기업은 
632곳에 불과하다 ICP 기업은 전략물자 수출관리를 위한 
내부자율준수규정을 일본 경제산업성에 제출하고 심사를 통해 인증받은 곳을 뜻한다
'''

# %%
# 4. 함수들을 적용하면데 텍스트를 분해해 보기
kkma.sentences( test_text )
# Out:
# ['일본이 한국을 백색국가( 수출 심사 우 대국 )에서 제외하는 수출무역관리령 개정안 시행 일이 열흘도 채 남지 않았다 정부는 자율 준수프로그램 (ICP) 인 증을 받은 일본 기업을 통하면 지금처럼 수입에 큰 어려움이 없을 것이라는 입장이다 다만 어떤 기업이 여기에 해당하는지 전체 명단의 절반도 파악하지 못했다는 점은 우려스럽다 19일 전략 물자 관리원과 코 트라 등에 따르면 일본 내 ICP 인증 기업은 1300여 곳으로 추정된다 이 가운데 사명을 공개한 기업은 632 곳에 불과 하다 ICP 기업은 전략 물자 수출관리를 위한 내부자율 준수규정을 일본 경제산업 성에 제출하고 심사를 통해 인증 받은 곳을 뜻한다']

# %%
test_text = '''
일본이 한국을 백색국가(수출 심사 우대국)에서 제외하는 수출무역관리령
개정안 시행일이 열흘도 채 남지 않았다. 정부는 자율준수프로그램(ICP) 
인증을 받은 일본 기업을 통하면 지금처럼 수입에 큰 어려움이 없을 것이라는 입장이다. 
다만 어떤 기업이 여기에 해당하는지 전체 명단의 절반도 
파악하지 못했다는 점은 우려스럽다.

19일 전략물자관리원과 코트라 등에 따르면 일본 
내 ICP 인증 기업은 1300여곳으로 추정된다. 이 가운데 사명을 공개한 기업은 
632곳에 불과하다. ICP 기업은 전략물자 수출관리를 위한 
내부자율준수규정을 일본 경제산업성에 제출하고 심사를 통해 인증받은 곳을 뜻한다.
'''

# %%
# 마침표를 기준점으로 문장의 끝을 판변한다. 
# -> 실제 리얼 데이터들은 마침표가 없을 가능성이 크다.
# 문장의 분해라는 관점에서는 부적절함이 보인다
tmp = kkma.sentences( test_text )
tmp
# Out:
# ['일본이 한국을 백색국가( 수출 심사 우 대국 )에서 제외하는 수출무역관리령 개정안 시행 일이 열흘도 채 남지 않았다.',
#  '정부는 자율 준수프로그램 (ICP) 인 증을 받은 일본 기업을 통하면 지금처럼 수입에 큰 어려움이 없을 것이라는 입장이다.',
#  '다만 어떤 기업이 여기에 해당하는지 전체 명단의 절반도 파악하지 못했다는 점은 우려스럽다.',
#  '19일 전략 물자 관리원과 코 트라 등에 따르면 일본 내 ICP 인증 기업은 1300여 곳으로 추정된다.',
#  '이 가운데 사명을 공개한 기업은 632 곳에 불과 하다. ICP 기업은 전략 물자 수출관리를 위한 내부자율 준수규정을 일본 경제산업 성에 제출하고 심사를 통해 인증 받은 곳을 뜻한다.']

# %%
len(tmp)
# Out:
# 5

# %%
for sen in tmp:
    print( "-"*10 )
    # 명사 추출
    word = kkma.nouns( sen )
    # 형태소 분석
    poses = kkma.pos( sen )
    morphses = kkma.morphs( sen )
    print( sen, word, poses, morphses )
    print( "-"*10 )
# Out:
# ----------
# 일본이 한국을 백색국가( 수출 심사 우 대국 )에서 제외하는 수출무역관리령 개정안 시행 일이 열흘도 채 남지 않았다. ['일본', '한국', '백색', '백색국가', '국가', '수출', '심사', '우', '대국', '제외', '수출무역관리', '무역', '관리', '개정안', '시행', '일', '열흘'] [('일본', 'NNG'), ('이', 'JKS'), ('한국', 'NNG'), ('을', 'JKO'), ('백색', 'NNG'), ('국가', 'NNG'), ('(', 'SS'), ('수출', 'NNG'), ('심사', 'NNG'), ('우', 'NNG'), ('대국', 'NNG'), (')', 'SS'), ('에서', 'JKM'), ('제외', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('수출', 'NNG'), ('무역', 'NNG'), ('관리', 'NNG'), ('령', 'XSN'), ('개정안', 'NNG'), ('시행', 'NNG'), ('일', 'NNG'), ('이', 'JKS'), ('열흘', 'NNG'), ('도', 'JX'), ('채', 'MAG'), ('남', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('았', 'EPT'), ('다', 'EFN'), ('.', 'SF')] ['일본', '이', '한국', '을', '백색', '국가', '(', '수출', '심사', '우', '대국', ')', '에서', '제외', '하', '는', '수출', '무역', '관리', '령', '개정안', '시행', '일', '이', '열흘', '도', '채', '남', '지', '않', '았', '다', '.']
# ----------
# ----------
# 정부는 자율 준수프로그램 (ICP) 인 증을 받은 일본 기업을 통하면 지금처럼 수입에 큰 어려움이 없을 것이라는 입장이다. ['정부', '자율', '준수', '준수프로그램', '프로그램', '증', '일본', '기업', '지금', '수입', '어려움', '입장'] [('정부', 'NNG'), ('는', 'JX'), ('자율', 'NNG'), ('준수', 'NNG'), ('프로그램', 'NNG'), ('(', 'SS'), ('ICP', 'OL'), (')', 'SS'), ('이', 'VCP'), ('ㄴ', 'ETD'), ('증', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('은', 'ETD'), ('일본', 'NNG'), ('기업', 'NNG'), ('을', 'JKO'), ('통하', 'VV'), ('면', 'ECE'), ('지금', 'NNG'), ('처럼', 'JKM'), ('수입', 'NNG'), ('에', 'JKM'), ('크', 'VA'), ('ㄴ', 'ETD'), ('어려움', 'NNG'), ('이', 'JKS'), ('없', 'VA'), ('을', 'ETD'), ('것', 'NNB'), ('이', 'VCP'), ('라는', 'ETD'), ('입장', 'NNG'), ('이', 'VCP'), ('다', 'EFN'), ('.', 'SF')] ['정부', '는', '자율', '준수', '프로그램', '(', 'ICP', ')', '이', 'ㄴ', '증', '을', '받', '은', '일본', '기업', '을', '통하', '면', '지금', '처럼', '수입', '에', '크', 'ㄴ', '어려움', '이', '없', '을', '것', '이', '라는', '입장', '이', '다', '.']
# ----------
# ----------
# 다만 어떤 기업이 여기에 해당하는지 전체 명단의 절반도 파악하지 못했다는 점은 우려스럽다. ['기업', '여기', '해당', '전체', '명단', '절반', '파악', '점', '우려'] [('다만', 'MAG'), ('어떤', 'MDT'), ('기업', 'NNG'), ('이', 'JKS'), ('여기', 'NP'), ('에', 'JKM'), ('해당', 'NNG'), ('하', 'XSV'), ('는지', 'ECS'), ('전체', 'NNG'), ('명단', 'NNG'), ('의', 'JKG'), ('절반', 'NNG'), ('도', 'JX'), ('파악', 'NNG'), ('하', 'XSV'), ('지', 'ECD'), ('못하', 'VX'), ('었', 'EPT'), ('다는', 'ETD'), ('점', 'NNG'), ('은', 'JX'), ('우려', 'NNG'), ('스럽', 'XSA'), ('다', 'EFN'), ('.', 'SF')] ['다만', '어떤', '기업', '이', '여기', '에', '해당', '하', '는지', '전체', '명단', '의', '절반', '도', '파악', '하', '지', '못하', '었', '다는', '점', '은', '우려', '스럽', '다', '.']
# ----------
# ----------
# 19일 전략 물자 관리원과 코 트라 등에 따르면 일본 내 ICP 인증 기업은 1300여 곳으로 추정된다. ['19', '19일', '일', '전략', '물자', '관리원', '코', '트라', '등', '일본', '내', '인증', '기업', '1300', '1300여', '여', '곳', '추정'] [('19', 'NR'), ('일', 'NNM'), ('전략', 'NNG'), ('물자', 'NNG'), ('관리원', 'NNG'), ('과', 'JC'), ('코', 'NNG'), ('트라', 'NNG'), ('등', 'NNB'), ('에', 'JKM'), ('따르', 'VV'), ('면', 'ECE'), ('일본', 'NNG'), ('내', 'NNB'), ('ICP', 'OL'), ('인증', 'NNG'), ('기업', 'NNG'), ('은', 'JX'), ('1300', 'NR'), ('여', 'NR'), ('곳', 'NNG'), ('으로', 'JKM'), ('추정', 'NNG'), ('되', 'XSV'), ('ㄴ다', 'EFN'), ('.', 'SF')] ['19', '일', '전략', '물자', '관리원', '과', '코', '트라', '등', '에', '따르', '면', '일본', '내', 'ICP', '인증', '기업', '은', '1300', '여', '곳', '으로', '추정', '되', 'ㄴ다', '.']
# ----------
# ----------
# 이 가운데 사명을 공개한 기업은 632 곳에 불과 하다. ICP 기업은 전략 물자 수출관리를 위한 내부자율 준수규정을 일본 경제산업 성에 제출하고 심사를 통해 인증 받은 곳을 뜻한다. ['가운데', '사명', '공개', '기업', '632', '곳', '하다', '전략', '물자', '수출', '수출관리', '관리', '내부자', '준수', '준수규정', '규정', '일본', '경제', '경제산업', '산업', '성에', '제출', '심사', '인증'] [('이', 'MDT'), ('가운데', 'NNG'), ('사명', 'NNG'), ('을', 'JKO'), ('공개', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('기업', 'NNG'), ('은', 'JX'), ('632', 'NR'), ('곳', 'NNG'), ('에', 'JKM'), ('불과', 'MAG'), ('하다', 'NNP'), ('.', 'SF'), ('ICP', 'OL'), ('기업', 'NNG'), ('은', 'JX'), ('전략', 'NNG'), ('물자', 'NNG'), ('수출', 'NNG'), ('관리', 'NNG'), ('를', 'JKO'), ('위하', 'VV'), ('ㄴ', 'ETD'), ('내부자', 'NNG'), ('율', 'XSN'), ('준수', 'NNG'), ('규정', 'NNG'), ('을', 'JKO'), ('일본', 'NNG'), ('경제', 'NNG'), ('산업', 'NNG'), ('성에', 'NNG'), ('제출', 'NNG'), ('하', 'XSV'), ('고', 'ECE'), ('심사', 'NNG'), ('를', 'JKO'), ('통하', 'VV'), ('어', 'ECS'), ('인증', 'NNG'), ('받', 'VV'), ('은', 'ETD'), ('곳', 'NNG'), ('을', 'JKO'), ('뜻하', 'VV'), ('ㄴ다', 'EFN'), ('.', 'SF')] ['이', '가운데', '사명', '을', '공개', '하', 'ㄴ', '기업', '은', '632', '곳', '에', '불과', '하다', '.', 'ICP', '기업', '은', '전략', '물자', '수출', '관리', '를', '위하', 'ㄴ', '내부자', '율', '준수', '규정', '을', '일본', '경제', '산업', '성에', '제출', '하', '고', '심사', '를', '통하', '어', '인증', '받', '은', '곳', '을', '뜻하', 'ㄴ다', '.']
# ----------

# %% [markdown]
# ### 한나눔

# %%
from konlpy.tag import Hannanum
hannanum = Hannanum()
# test_text  사용

# %%
# pos 분석을 진행하여 계층 구조 정립
hannanum.analyze( test_text )
# Out:
# [[[('일', 'nnc'), ('본', 'nbu'), ('이', 'jcc')],
#   [('일', 'nnc'), ('본', 'nbu'), ('이', 'jcs')]],
#  [[('한국', 'ncn'), ('을', 'jco')],
#   [('한국을', 'ncn')],
#   [('한국', 'nqq'), ('을', 'jco')],
#   [('한국을', 'nqq')]],
#  [[('백색국가', 'ncn'), ('(', 'sl'), ('수출', 'ncpa')],
#   [('백색국가(수출', 'ncn')],
#   [('백색국가', 'nqq'), ('(', 'sl'), ('수출', 'ncpa')],
#   [('백색국가(수출', 'nqq')]],
#  [[('심사', 'ncn')], [('심사', 'ncpa')]],
#  [[('우대', 'ncpa'), ('국', 'ncn'), (')', 'sr'), ('에서', 'jca')]],
#  [[('제외', 'ncpa'), ('하', 'xsva'), ('는', 'etm')],
#   [('제외', 'ncpa'), ('하', 'xsva'), ('어', 'ecs'), ('는', 'jxc')],
#   [('제외', 'ncpa'), ('하', 'xsva'), ('어', 'ef'), ('는', 'etm')]],
#  [[('수출', 'ncpa'), ('무역', 'ncpa'), ('관리', 'ncn'), ('령', 'ncn')],
#   [('수출', 'ncpa'), ('무역', 'ncpa'), ('관리', 'ncpa'), ('령', 'ncn')]],
#  [],
#  [[('개정안', 'ncn')],
#   [('개정', 'ncpa'), ('안', 'ncn')],
#   [('개정', 'ncpa'), ('안', 'xsnx')]],
#  [[('시행', 'ncpa'), ('일', 'ncn'), ('이', 'jcc')],
#   [('시행', 'ncpa'), ('일', 'ncn'), ('이', 'jcs')],
#   [('시행', 'ncpa'), ('일', 'ncpa'), ('이', 'jcc')],
#   [('시행', 'ncpa'), ('일', 'ncpa'), ('이', 'jcs')],
#   [('시행', 'ncpa'), ('일', 'ncps'), ('이', 'jcc')],
#   [('시행', 'ncpa'), ('일', 'ncps'), ('이', 'jcs')]],
#  [[('열흘', 'ncn'), ('도', 'jxc')], [('열흘', 'ncn'), ('도', 'ncn')]],
#  [[('채', 'nbn')], [('채', 'ncn')]],
#  [[('남지', 'ncn')],
#   [('남', 'pvg'), ('지', 'ecs')],
#   [('남', 'pvg'), ('지', 'ecx')],
#   [('남', 'pvg'), ('지', 'ef')]],
#  [[('않', 'px'), ('아', 'ep'), ('다', 'ef')]],
#  [[('.', 'sf')], [('.', 'sy')]],
#  [],
#  [[('정부', 'ncn'), ('는', 'jxc')]],
#  [[('자율준수프로그램', 'ncn'), ('(', 'sl'), ('ICP', 'f'), (')', 'sr')],
#   [('자율준수프로그램(ICP', 'ncn'), (')', 'sr')],
#   [('자율준수프로그램(ICP)', 'ncn')],
#   [('자율준수프로그램', 'nqq'), ('(', 'sl'), ('ICP', 'f'), (')', 'sr')],
#   [('자율준수프로그램(ICP', 'nqq'), (')', 'sr')],
#   [('자율준수프로그램(ICP)', 'nqq')]],
#  [],
#  [[('인증', 'ncpa'), ('을', 'jco')]],
#  [[('받', 'pvg'), ('은', 'etm')], [('받', 'px'), ('은', 'etm')]],
#  [[('일', 'nnc'), ('본', 'nbu')]],
#  [[('기업', 'ncn'), ('을', 'jco')], [('기업', 'ncpa'), ('을', 'jco')]],
#  [[('통하', 'pvg'), ('면', 'ecs')]],
#  [[('지금', 'mag'), ('처럼', 'jxc')],
#   [('지금', 'ncn'), ('처럼', 'jca')],
#   [('지금', 'ncn'), ('처럼', 'jxc')]],
#  [[('수입', 'ncpa'), ('에', 'jca')]],
#  [[('크', 'paa'), ('ㄴ', 'etm')]],
#  [[('어려움', 'ncn'), ('이', 'jcc')],
#   [('어려움', 'ncn'), ('이', 'jcs')],
#   [('어려움', 'ncn'), ('이', 'ncn')],
#   [('어렵', 'paa'), ('음', 'etn'), ('이', 'jcc')],
#   [('어렵', 'paa'), ('음', 'etn'), ('이', 'jcs')]],
#  [[('없', 'paa'), ('을', 'etm')]],
#  [[('것', 'nbn'), ('이라는', 'jcm')],
#   [('것', 'nbn'), ('이라', 'jca'), ('는', 'jxc')],
#   [('것', 'nbn'), ('이', 'jcc'), ('라는', 'jxc')],
#   [('것', 'nbn'), ('이', 'jcs'), ('라는', 'jxc')],
#   [('것', 'nbn'), ('이', 'jp'), ('라는', 'etm')],
#   [('것', 'nbn'), ('이', 'jp'), ('라는', 'etm')],
#   [('것', 'nbn'), ('이', 'jp'), ('라', 'ecs'), ('는', 'jxc')],
#   [('것', 'nbn'), ('이', 'jp'), ('라', 'ef'), ('는', 'etm')]],
#  [[('입장', 'ncpa'), ('이', 'jp'), ('다', 'ef')],
#   [('입장', 'ncpa'), ('이', 'ncn'), ('이', 'jp'), ('다', 'ef')]],
#  [[('.', 'sf')], [('.', 'sy')]],
#  [],
#  [[('다만', 'mag')]],
#  [[('어떤', 'mmd')]],
#  [[('기업', 'ncn'), ('이', 'jcc')],
#   [('기업', 'ncn'), ('이', 'jcs')],
#   [('기업', 'ncn'), ('이', 'ncn')],
#   [('기업', 'ncpa'), ('이', 'jcc')],
#   [('기업', 'ncpa'), ('이', 'jcs')],
#   [('기업', 'ncpa'), ('이', 'ncn')]],
#  [[('여기', 'npd'), ('에', 'jca')],
#   [('여', 'ncn'), ('이', 'jp'), ('기', 'etn'), ('에', 'jca')]],
#  [[('해당', 'ncpa'), ('하', 'xsva'), ('는지', 'ecc')],
#   [('해당', 'ncpa'), ('하', 'xsva'), ('는지', 'ecs')],
#   [('해당', 'ncpa'), ('하', 'xsva'), ('는지', 'ef')],
#   [('해당', 'ncpa'), ('하', 'xsva'), ('는', 'etm'), ('지', 'nbn')],
#   [('해당', 'ncpa'), ('하', 'xsva'), ('어', 'ef'), ('는', 'etm'), ('지', 'nbn')]],
#  [[('전체', 'ncn')],
#   [('전', 'xp'), ('체', 'ncn')],
#   [('절', 'pvg'), ('ㄴ', 'etm'), ('체', 'nbs')]],
#  [[('명단', 'ncn'), ('의', 'jcm')], [('명단', 'ncn'), ('의', 'ncn')]],
#  [[('절반', 'ncn'), ('도', 'jxc')], [('절반', 'ncn'), ('도', 'ncn')]],
#  [],
#  [[('파악', 'ncpa'), ('하', 'xsva'), ('지', 'ecs')],
#   [('파악', 'ncpa'), ('하', 'xsva'), ('지', 'ecx')],
#   [('파악', 'ncpa'), ('하', 'xsva'), ('지', 'ef')]],
#  [[('못하', 'paa'), ('었', 'ep'), ('다는', 'etm')],
#   [('못하', 'paa'), ('었', 'ep'), ('다', 'ef'), ('는', 'etm')],
#   [('못하', 'pvg'), ('었', 'ep'), ('다는', 'etm')],
#   [('못하', 'pvg'), ('었', 'ep'), ('다', 'ef'), ('는', 'etm')],
#   [('못하', 'px'), ('었', 'ep'), ('다는', 'etm')],
#   [('못하', 'px'), ('었', 'ep'), ('다', 'ef'), ('는', 'etm')]],
#  [[('점', 'nbu'), ('은', 'jxc')],
#   [('점', 'ncn'), ('은', 'jxc')],
#   [('절', 'pvg'), ('ㅁ', 'etn'), ('은', 'jxc')]],
#  [[('우려', 'ncpa'), ('스럽', 'xsmn'), ('다', 'ef')],
#   [('우', 'ncn'), ('이', 'jp'), ('려', 'ecx'), ('스럽', 'px'), ('다', 'ef')],
#   [('우', 'ncn'),
#    ('이', 'jp'),
#    ('리', 'ep'),
#    ('어', 'ecx'),
#    ('스럽', 'px'),
#    ('다', 'ef')]],
#  [[('.', 'sf')], [('.', 'sy')]],
#  [],
#  [[('19', 'nnc'), ('일', 'nbu')],
#   [('19', 'nnc'), ('일', 'nnc')],
#   [('19', 'nnc'), ('이', 'jp'), ('ㄹ', 'etm')]],
#  [[('전략물자', 'ncn'), ('관리', 'ncn'), ('원', 'ncn'), ('과', 'jcj')],
#   [('전략물자', 'ncn'), ('관리', 'ncn'), ('원', 'ncn'), ('과', 'jct')],
#   [('전략물자', 'ncn'), ('관리', 'ncpa'), ('원', 'ncn'), ('과', 'jcj')],
#   [('전략물자', 'ncn'), ('관리', 'ncpa'), ('원', 'ncn'), ('과', 'jct')],
#   [('전략', 'ncn'), ('물자', 'ncn'), ('관리', 'ncn'), ('원', 'ncn'), ('과', 'jcj')],
#   [('전략', 'ncn'), ('물자', 'ncn'), ('관리', 'ncn'), ('원', 'ncn'), ('과', 'jct')],
#   [('전략', 'ncn'), ('물자', 'ncn'), ('관리', 'ncpa'), ('원', 'ncn'), ('과', 'jcj')],
#   [('전략', 'ncn'), ('물자', 'ncn'), ('관리', 'ncpa'), ('원', 'ncn'), ('과', 'jct')]],
#  [[('코트', 'ncn'), ('라', 'ncn')],
#   [('코트', 'ncn'), ('이', 'jp'), ('라', 'ecs')],
#   [('코트', 'ncn'), ('이', 'jp'), ('라', 'ef')]],
#  [[('등에', 'ncn')],
#   [('등', 'nbn'), ('에', 'jca')],
#   [('등', 'nbu'), ('에', 'jca')],
#   [('등', 'ncn'), ('에', 'jca')]],
#  [[('따르', 'pvg'), ('면', 'ecs')]],
#  [[('일', 'nnc'), ('본', 'nbu')]],
#  [],
#  [[('내', 'nbn')],
#   [('내', 'ncn')],
#   [('내', 'npp')],
#   [('내', 'pvg'), ('어', 'ecs')],
#   [('내', 'pvg'), ('어', 'ecx')],
#   [('내', 'pvg'), ('어', 'ef')],
#   [('내', 'px'), ('어', 'ecs')],
#   [('내', 'px'), ('어', 'ecx')],
#   [('내', 'px'), ('어', 'ef')]],
#  [[('ICP', 'f')]],
#  [[('인증', 'ncpa')]],
#  [[('기업', 'ncn'), ('은', 'jxc')],
#   [('기업', 'ncn'), ('은', 'ncn')],
#   [('기업', 'ncpa'), ('은', 'jxc')],
#   [('기업', 'ncpa'), ('은', 'ncn')]],
#  [[('1300', 'nnc'), ('여', 'xsnu'), ('곳', 'nbu'), ('으로', 'jca')]],
#  [[('추정', 'ncpa'), ('되', 'xsvn'), ('ㄴ다', 'ef')]],
#  [[('.', 'sf')], [('.', 'sy')]],
#  [],
#  [[('이', 'mmd')], [('이', 'ncn')], [('이', 'nnc')], [('이', 'npd')]],
#  [[('가운데', 'ncn')]],
#  [[('사명', 'ncn'), ('을', 'jco')], [('사', 'nnc'), ('명', 'nbu'), ('을', 'jco')]],
#  [[('공개', 'ncpa'), ('한', 'ncn')],
#   [('공개', 'ncpa'), ('하', 'xsva'), ('ㄴ', 'etm')]],
#  [[('기업', 'ncn'), ('은', 'jxc')],
#   [('기업', 'ncn'), ('은', 'ncn')],
#   [('기업', 'ncpa'), ('은', 'jxc')],
#   [('기업', 'ncpa'), ('은', 'ncn')]],
#  [],
#  [[('632', 'nnc'), ('곳', 'nbu'), ('에', 'jca')]],
#  [[('불과', 'ncps'), ('하', 'xsms'), ('다', 'ef')],
#   [('불과', 'ncps'), ('하', 'xsms'), ('어다', 'ecs')],
#   [('불과', 'ncps'), ('하', 'xsms'), ('어다', 'ecx')]],
#  [[('.', 'sf')], [('.', 'sy')]],
#  [],
#  [[('ICP', 'f')]],
#  [[('기업', 'ncn'), ('은', 'jxc')],
#   [('기업', 'ncn'), ('은', 'ncn')],
#   [('기업', 'ncpa'), ('은', 'jxc')],
#   [('기업', 'ncpa'), ('은', 'ncn')]],
#  [[('전략물자', 'ncn')], [('전략', 'ncn'), ('물자', 'ncn')]],
#  [[('수출관리', 'ncn'), ('를', 'jco')],
#   [('수출', 'ncpa'), ('관리', 'ncn'), ('를', 'jco')],
#   [('수출', 'ncpa'), ('관리', 'ncpa'), ('를', 'jco')]],
#  [[('위하', 'pvg'), ('ㄴ', 'etm')]],
#  [],
#  [[('내부', 'ncn'), ('자율', 'ncn'), ('준수', 'ncpa'), ('규정', 'ncn'), ('을', 'jco')],
#   [('내부', 'ncn'), ('자율', 'ncn'), ('준수', 'ncpa'), ('규정', 'ncpa'), ('을', 'jco')],
#   [('내부', 'ncn'), ('자율', 'ncn'), ('준수', 'ncps'), ('규정', 'ncn'), ('을', 'jco')],
#   [('내부', 'ncn'),
#    ('자율', 'ncn'),
#    ('준수', 'ncps'),
#    ('규정', 'ncpa'),
#    ('을', 'jco')]],
#  [[('일', 'nnc'), ('본', 'nbu')]],
#  [[('경제', 'ncn'), ('산업', 'ncn'), ('성에', 'ncn')],
#   [('경제', 'ncn'), ('산업', 'ncn'), ('성', 'ncn'), ('에', 'jca')]],
#  [[('제출', 'ncpa'), ('하고', 'jcj')],
#   [('제출', 'ncpa'), ('하고', 'jct')],
#   [('제출', 'ncpa'), ('하', 'xsva'), ('고', 'ecc')],
#   [('제출', 'ncpa'), ('하', 'xsva'), ('고', 'ecs')],
#   [('제출', 'ncpa'), ('하', 'xsva'), ('고', 'ecx')],
#   [('제출', 'ncpa'), ('하', 'xsva'), ('어', 'ef'), ('고', 'jcr')],
#   [('제', 'xp'), ('출하', 'ncn'), ('고', 'jcj')],
#   [('제', 'xp'), ('출하', 'ncn'), ('고', 'ncn')],
#   [('제', 'xp'), ('출하', 'ncn'), ('이', 'jp'), ('고', 'ecc')],
#   [('제', 'xp'), ('출하', 'ncn'), ('이', 'jp'), ('고', 'ecs')],
#   [('제', 'xp'), ('출하', 'ncn'), ('이', 'jp'), ('고', 'ecx')]],
#  [[('심사', 'ncn'), ('를', 'jco')], [('심사', 'ncpa'), ('를', 'jco')]],
#  [[('통하', 'pvg'), ('어', 'ecs')]],
#  [[('인증', 'ncpa'), ('받', 'xsva'), ('은', 'etm')]],
#  [[('곳', 'nbu'), ('을', 'jco')], [('곳', 'ncn'), ('을', 'jco')]],
#  [[('뜻', 'ncpa'), ('하', 'xsva'), ('ㄴ다', 'ef')],
#   [('뜻', 'ncps'), ('하', 'xsms'), ('ㄴ다', 'ef')]],
#  [[('.', 'sf')], [('.', 'sy')]]]

# %%
hannanum.nouns( test_text )
# Out:
# ['일본',
#  '한국',
#  '백색국가(수출',
#  '심사',
#  '우대국',
#  '제외',
#  '수출무역관리령',
#  '개정안',
#  '시행일',
#  '열흘',
#  '채',
#  '정부',
#  '자율준수프로그램',
#  '인증',
#  '일본',
#  '기업',
#  '지금',
#  '수입',
#  '어려움',
#  '것',
#  '입장',
#  '기업',
#  '여기',
#  '해당',
#  '전체',
#  '명단',
#  '절반',
#  '파악',
#  '점',
#  '우',
#  '19',
#  '전략물자관리원',
#  '코트',
#  '등',
#  '일본',
#  '내',
#  '인증',
#  '기업',
#  '1300',
#  '곳',
#  '추정',
#  '가운데',
#  '사명',
#  '공개',
#  '기업',
#  '632곳',
#  '불과',
#  '기업',
#  '전략물자',
#  '수출관리',
#  '내부자율준수규정',
#  '일본',
#  '경제산업성',
#  '제출',
#  '심사',
#  '인증',
#  '곳',
#  '뜻']

# %%
hannanum.morphs( test_text )
# Out:
# ['일본',
#  '이',
#  '한국',
#  '을',
#  '백색국가(수출',
#  '심사',
#  '우대국',
#  ')',
#  '에서',
#  '제외',
#  '하',
#  '는',
#  '수출무역관리령',
#  '개정안',
#  '시행일',
#  '이',
#  '열흘',
#  '도',
#  '채',
#  '남',
#  '지',
#  '않',
#  '아다',
#  '.',
#  '정부',
#  '는',
#  '자율준수프로그램',
#  '(',
#  'ICP',
#  ')',
#  '인증',
#  '을',
#  '받',
#  '은',
#  '일본',
#  '기업',
#  '을',
#  '통하',
#  '면',
#  '지금',
#  '처럼',
#  '수입',
#  '에',
#  '크',
#  'ㄴ',
#  '어려움',
#  '이',
#  '없',
#  '을',
#  '것',
#  '이',
#  '라는',
#  '입장',
#  '이',
#  '다',
#  '.',
#  '다만',
#  '어떤',
#  '기업',
#  '이',
#  '여기',
#  '에',
#  '해당',
#  '하',
#  '는지',
#  '전체',
#  '명단',
#  '의',
#  '절반',
#  '도',
#  '파악',
#  '하',
#  '지',
#  '못하',
#  '었다는',
#  '점',
#  '은',
#  '우',
#  '이',
#  '리어',
#  '스럽',
#  '다',
#  '.',
#  '19',
#  '이',
#  'ㄹ',
#  '전략물자관리원',
#  '과',
#  '코트',
#  '이',
#  '라',
#  '등',
#  '에',
#  '따르',
#  '면',
#  '일본',
#  '내',
#  'ICP',
#  '인증',
#  '기업',
#  '은',
#  '1300',
#  '여',
#  '곳',
#  '으로',
#  '추정',
#  '되',
#  'ㄴ다',
#  '.',
#  '이',
#  '가운데',
#  '사명',
#  '을',
#  '공개',
#  '하',
#  'ㄴ',
#  '기업',
#  '은',
#  '632곳',
#  '에',
#  '불과',
#  '하',
#  '다',
#  '.',
#  'ICP',
#  '기업',
#  '은',
#  '전략물자',
#  '수출관리',
#  '를',
#  '위하',
#  'ㄴ',
#  '내부자율준수규정',
#  '을',
#  '일본',
#  '경제산업성',
#  '에',
#  '제출',
#  '하고',
#  '심사',
#  '를',
#  '통하',
#  '어',
#  '인증',
#  '받',
#  '은',
#  '곳',
#  '을',
#  '뜻',
#  '하',
#  'ㄴ다',
#  '.']

# %%
hannanum.pos( test_text )
# Out:
# [('일본', 'N'),
#  ('이', 'J'),
#  ('한국', 'N'),
#  ('을', 'J'),
#  ('백색국가(수출', 'N'),
#  ('심사', 'N'),
#  ('우대국', 'N'),
#  (')', 'S'),
#  ('에서', 'J'),
#  ('제외', 'N'),
#  ('하', 'X'),
#  ('는', 'E'),
#  ('수출무역관리령', 'N'),
#  ('개정안', 'N'),
#  ('시행일', 'N'),
#  ('이', 'J'),
#  ('열흘', 'N'),
#  ('도', 'J'),
#  ('채', 'N'),
#  ('남', 'P'),
#  ('지', 'E'),
#  ('않', 'P'),
#  ('아다', 'E'),
#  ('.', 'S'),
#  ('정부', 'N'),
#  ('는', 'J'),
#  ('자율준수프로그램', 'N'),
#  ('(', 'S'),
#  ('ICP', 'F'),
#  (')', 'S'),
#  ('인증', 'N'),
#  ('을', 'J'),
#  ('받', 'P'),
#  ('은', 'E'),
#  ('일본', 'N'),
#  ('기업', 'N'),
#  ('을', 'J'),
#  ('통하', 'P'),
#  ('면', 'E'),
#  ('지금', 'N'),
#  ('처럼', 'J'),
#  ('수입', 'N'),
#  ('에', 'J'),
#  ('크', 'P'),
#  ('ㄴ', 'E'),
#  ('어려움', 'N'),
#  ('이', 'J'),
#  ('없', 'P'),
#  ('을', 'E'),
#  ('것', 'N'),
#  ('이', 'J'),
#  ('라는', 'E'),
#  ('입장', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('다만', 'M'),
#  ('어떤', 'M'),
#  ('기업', 'N'),
#  ('이', 'J'),
#  ('여기', 'N'),
#  ('에', 'J'),
#  ('해당', 'N'),
#  ('하', 'X'),
#  ('는지', 'E'),
#  ('전체', 'N'),
#  ('명단', 'N'),
#  ('의', 'J'),
#  ('절반', 'N'),
#  ('도', 'J'),
#  ('파악', 'N'),
#  ('하', 'X'),
#  ('지', 'E'),
#  ('못하', 'P'),
#  ('었다는', 'E'),
#  ('점', 'N'),
#  ('은', 'J'),
#  ('우', 'N'),
#  ('이', 'J'),
#  ('리어', 'E'),
#  ('스럽', 'P'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('19', 'N'),
#  ('이', 'J'),
#  ('ㄹ', 'E'),
#  ('전략물자관리원', 'N'),
#  ('과', 'J'),
#  ('코트', 'N'),
#  ('이', 'J'),
#  ('라', 'E'),
#  ('등', 'N'),
#  ('에', 'J'),
#  ('따르', 'P'),
#  ('면', 'E'),
#  ('일본', 'N'),
#  ('내', 'N'),
#  ('ICP', 'F'),
#  ('인증', 'N'),
#  ('기업', 'N'),
#  ('은', 'J'),
#  ('1300', 'N'),
#  ('여', 'X'),
#  ('곳', 'N'),
#  ('으로', 'J'),
#  ('추정', 'N'),
#  ('되', 'X'),
#  ('ㄴ다', 'E'),
#  ('.', 'S'),
#  ('이', 'M'),
#  ('가운데', 'N'),
#  ('사명', 'N'),
#  ('을', 'J'),
#  ('공개', 'N'),
#  ('하', 'X'),
#  ('ㄴ', 'E'),
#  ('기업', 'N'),
#  ('은', 'J'),
#  ('632곳', 'N'),
#  ('에', 'J'),
#  ('불과', 'N'),
#  ('하', 'X'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('ICP', 'F'),
#  ('기업', 'N'),
#  ('은', 'J'),
#  ('전략물자', 'N'),
#  ('수출관리', 'N'),
#  ('를', 'J'),
#  ('위하', 'P'),
#  ('ㄴ', 'E'),
#  ('내부자율준수규정', 'N'),
#  ('을', 'J'),
#  ('일본', 'N'),
#  ('경제산업성', 'N'),
#  ('에', 'J'),
#  ('제출', 'N'),
#  ('하고', 'J'),
#  ('심사', 'N'),
#  ('를', 'J'),
#  ('통하', 'P'),
#  ('어', 'E'),
#  ('인증', 'N'),
#  ('받', 'X'),
#  ('은', 'E'),
#  ('곳', 'N'),
#  ('을', 'J'),
#  ('뜻', 'N'),
#  ('하', 'X'),
#  ('ㄴ다', 'E'),
#  ('.', 'S')]

# %% [markdown]
# ### 트위터

# %%
from konlpy.tag import Okt
from konlpy.tag import Twitter
# Twitter -> Okt

# %%
t = Okt()

# %%
# 어구 추출
t.phrases( test_text ), len(t.phrases( test_text ))
# Out:
# (['일본',
#   '한국',
#   '백색국가',
#   '수출',
#   '수출 심사',
#   '수출 심사 우대국',
#   '제외',
#   '제외하는 수출무역관리령',
#   '개정안',
#   '개정안 시행일',
#   '열흘',
#   '채 남지',
#   '정부',
#   '자율준수프로그램',
#   'ICP',
#   '인증',
#   '일본 기업',
#   '통하면 지금',
#   '수입',
#   '어려움',
#   '없을 것',
#   '입장',
#   '다만',
#   '다만 어떤 기업',
#   '여기',
#   '해당',
#   '전체',
#   '전체 명단',
#   '전체 명단의 절반',
#   '파악',
#   '못했다는 점',
#   '우려',
#   '19일',
#   '19일 전략물자관리원',
#   '19일 전략물자관리원과 코트라',
#   '19일 전략물자관리원과 코트라 등',
#   '일본 \n내',
#   '일본 \n내 ICP',
#   '일본 \n내 ICP 인증',
#   '일본 \n내 ICP 인증 기업',
#   '1300여곳',
#   '추정',
#   '이 가운데',
#   '이 가운데 사명',
#   '공개',
#   '기업',
#   '632곳',
#   'ICP 기업',
#   '전략물자',
#   '전략물자 수출관리',
#   '내부자율준수규정',
#   '일본 경제산업성',
#   '제출',
#   '심사',
#   '통해',
#   '통해 인증',
#   '통해 인증받은 곳',
#   '백색',
#   '국가',
#   '우대',
#   '무역',
#   '관리',
#   '시행일',
#   '남지',
#   '자율',
#   '준수',
#   '프로그램',
#   '지금',
#   '명단',
#   '절반',
#   '전략물자관리원',
#   '코트라',
#   '1300',
#   '여곳',
#   '가운데',
#   '사명',
#   '632',
#   '전략',
#   '물자',
#   '내부',
#   '규정',
#   '경제산업성'],
#  82)

# %%
t.nouns( test_text ), len(t.nouns( test_text ))
# Out:
# (['일본',
#   '한국',
#   '백색',
#   '국가',
#   '수출',
#   '심사',
#   '우대',
#   '국',
#   '제외',
#   '수출',
#   '무역',
#   '관리',
#   '령',
#   '개정안',
#   '시행일',
#   '열흘',
#   '채',
#   '남지',
#   '정부',
#   '자율',
#   '준수',
#   '프로그램',
#   '인증',
#   '일본',
#   '기업',
#   '통',
#   '지금',
#   '수입',
#   '어려움',
#   '것',
#   '입장',
#   '다만',
#   '기업',
#   '여기',
#   '해당',
#   '전체',
#   '명단',
#   '절반',
#   '파악',
#   '점',
#   '우려',
#   '전략물자관리원',
#   '코트라',
#   '등',
#   '일본',
#   '내',
#   '인증',
#   '기업',
#   '곳',
#   '추정',
#   '이',
#   '가운데',
#   '사명',
#   '공개',
#   '기업',
#   '곳',
#   '기업',
#   '전략',
#   '물자',
#   '수출',
#   '관리',
#   '위',
#   '내부',
#   '자율',
#   '준수',
#   '규정',
#   '일본',
#   '경제산업성',
#   '제출',
#   '심사',
#   '통해',
#   '인증',
#   '곳',
#   '뜻'],
#  74)

# %%
t.pos( test_text )
# Out:
# [('\n', 'Foreign'),
#  ('일본', 'Noun'),
#  ('이', 'Josa'),
#  ('한국', 'Noun'),
#  ('을', 'Josa'),
#  ('백색', 'Noun'),
#  ('국가', 'Noun'),
#  ('(', 'Punctuation'),
#  ('수출', 'Noun'),
#  ('심사', 'Noun'),
#  ('우대', 'Noun'),
#  ('국', 'Noun'),
#  (')', 'Punctuation'),
#  ('에서', 'Josa'),
#  ('제외', 'Noun'),
#  ('하는', 'Verb'),
#  ('수출', 'Noun'),
#  ('무역', 'Noun'),
#  ('관리', 'Noun'),
#  ('령', 'Noun'),
#  ('\n', 'Foreign'),
#  ('개정안', 'Noun'),
#  ('시행일', 'Noun'),
#  ('이', 'Josa'),
#  ('열흘', 'Noun'),
#  ('도', 'Josa'),
#  ('채', 'Noun'),
#  ('남지', 'Noun'),
#  ('않았다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('정부', 'Noun'),
#  ('는', 'Josa'),
#  ('자율', 'Noun'),
#  ('준수', 'Noun'),
#  ('프로그램', 'Noun'),
#  ('(', 'Punctuation'),
#  ('ICP', 'Alpha'),
#  (')', 'Punctuation'),
#  ('인증', 'Noun'),
#  ('을', 'Josa'),
#  ('받은', 'Verb'),
#  ('일본', 'Noun'),
#  ('기업', 'Noun'),
#  ('을', 'Josa'),
#  ('통', 'Noun'),
#  ('하면', 'Verb'),
#  ('지금', 'Noun'),
#  ('처럼', 'Josa'),
#  ('수입', 'Noun'),
#  ('에', 'Josa'),
#  ('큰', 'Verb'),
#  ('어려움', 'Noun'),
#  ('이', 'Josa'),
#  ('없을', 'Adjective'),
#  ('것', 'Noun'),
#  ('이라는', 'Josa'),
#  ('입장', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('다만', 'Noun'),
#  ('어떤', 'Adjective'),
#  ('기업', 'Noun'),
#  ('이', 'Josa'),
#  ('여기', 'Noun'),
#  ('에', 'Josa'),
#  ('해당', 'Noun'),
#  ('하는지', 'Verb'),
#  ('전체', 'Noun'),
#  ('명단', 'Noun'),
#  ('의', 'Josa'),
#  ('절반', 'Noun'),
#  ('도', 'Josa'),
#  ('파악', 'Noun'),
#  ('하지', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('했다는', 'Verb'),
#  ('점', 'Noun'),
#  ('은', 'Josa'),
#  ('우려', 'Noun'),
#  ('스럽다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('19일', 'Number'),
#  ('전략물자관리원', 'Noun'),
#  ('과', 'Josa'),
#  ('코트라', 'Noun'),
#  ('등', 'Noun'),
#  ('에', 'Josa'),
#  ('따르면', 'Verb'),
#  ('일본', 'Noun'),
#  ('내', 'Noun'),
#  ('ICP', 'Alpha'),
#  ('인증', 'Noun'),
#  ('기업', 'Noun'),
#  ('은', 'Josa'),
#  ('1300', 'Number'),
#  ('여', 'Modifier'),
#  ('곳', 'Noun'),
#  ('으로', 'Josa'),
#  ('추정', 'Noun'),
#  ('된다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('이', 'Noun'),
#  ('가운데', 'Noun'),
#  ('사명', 'Noun'),
#  ('을', 'Josa'),
#  ('공개', 'Noun'),
#  ('한', 'Josa'),
#  ('기업', 'Noun'),
#  ('은', 'Josa'),
#  ('632', 'Number'),
#  ('곳', 'Noun'),
#  ('에', 'Josa'),
#  ('불과하다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('ICP', 'Alpha'),
#  ('기업', 'Noun'),
#  ('은', 'Josa'),
#  ('전략', 'Noun'),
#  ('물자', 'Noun'),
#  ('수출', 'Noun'),
#  ('관리', 'Noun'),
#  ('를', 'Josa'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('내부', 'Noun'),
#  ('자율', 'Noun'),
#  ('준수', 'Noun'),
#  ('규정', 'Noun'),
#  ('을', 'Josa'),
#  ('일본', 'Noun'),
#  ('경제산업성', 'Noun'),
#  ('에', 'Josa'),
#  ('제출', 'Noun'),
#  ('하고', 'Josa'),
#  ('심사', 'Noun'),
#  ('를', 'Josa'),
#  ('통해', 'Noun'),
#  ('인증', 'Noun'),
#  ('받은', 'Verb'),
#  ('곳', 'Noun'),
#  ('을', 'Josa'),
#  ('뜻', 'Noun'),
#  ('한다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign')]

# %% [markdown]
# ### 형태소 분석기는 트위터를 사용
# - 워드클라우드를 사용하여 지문의 중요 단어들 표시
# - 이미지(해당 내용을 좀더 부각)위에 마스킹 처리하여서 시각화
# - stopword 항목을 통해서 부적절한 용어나, 제거한 단어들을 빼고 처리
# - 연관어 유사어등등 항목들을 구성하여 표현

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
import numpy as np
from PIL import Image

# %%
with open('./data/alice.txt') as f:
    text = f.read()
text[:100], len(text)
# Out:
# ("Project Gutenberg's Alice's Adventures in Wonderland, by Lewis Carroll\n\nThis eBook is for the use of",
#  145187)

# %%
# 이미지 마스킹
alice_mask = np.array( Image.open( './data/alice_mask.png' ) )
alice_mask.shape
# Out:
# (900, 900)

# %%
# 시각화 준비
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 한글 처리
from korea_font import initKoreaFontLoad
initKoreaFontLoad()
# Out:
# Malgun Gothic

# %%
# 이미지 그리기
plt.figure(figsize=(8,8))
# interpolation='bilinear' <= 이미지를 그리는 처리에 중요한 부분
# 이중선형 보간법 설정, 1차원 선형보간법을 2차원으로 확장한다는 의미
plt.imshow( alice_mask, cmap=plt.cm.gray, interpolation='bilinear' )
# 축을 제거
plt.axis('off')
plt.show()

# %%
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
# 카운팅에 배제되는 단어
# 단어로 사용되지 않는 영어문자들을 모아둔것 : STOPWORDS
# 추가로 배제 가능
stopwords = set( STOPWORDS )
# 만약에 특정 단어를 추가하고 싶다면
stopwords.add( 'said' )
len(stopwords)
# Out:
# 191

# %%
# 워드 클라우드 생성 
# 워드 카운트 기능 제공
wc = WordCloud( background_color='white', 
           max_words=2000, 
           mask=alice_mask, 
           stopwords=stopwords)

# %%
# 워드 카운트 수행
wc = wc.generate( text )

# %%
len( wc.words_ ), type(wc.words_)
# Out:
# (2000, dict)

# %%
# 최대 빈도 word를 1.0으로 두고, 나머지는 0까지 정규화 하였다
wc.words_
'''
ouptut:
{'Alice': 1.0,
 'little': 0.2958904109589041,
 'one': 0.2602739726027397,
 'know': 0.2465753424657534,
 'went': 0.2273972602739726,
 ...
'''

# %%
# 최종 시각화
plt.figure(figsize=(12,12))
plt.imshow( wc, interpolation='bilinear' )
plt.axis('off')
plt.show()

# %% [markdown]
# ###  스타워즈 텍스트

# %%
# 텍스트 원문 -> 정제작업
with open( './data/star_wars.txt' ) as f:
    text = f.read()

# %%
text[:100], len(text)
# Out:
# ('\n\n                                        STAR WARS\n\n                                        Episode',
#  326361)

# %%
# 같은 단어(이름) 인데 표현을 다양해서 다르게 인식될수 있다
text.find('HAN'), text.find('Han')
# Out:
# (113272, 113039)

# %%
text = text.replace( 'HAN', 'Han' )

# %%
text.find('HAN'), text.find('Han')
# Out:
# (-1, 113039)

# %%
text.find("LUKE'S"), text.find('Luke')
# Out:
# (70466, 5405)

# %%
text = text.replace( "LUKE'S", 'Luke' ) 
# 이하 작업은 워드클라우드 시각화후 판단하여 텍스트의 내용을 조정(전처리)후 다시 처리
# 하는 과정을 미리 수행한것이다.

# %%
# 스탑워드 -> 카운트 제거 단어 추가분
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)
# 추가 단어는 시각화 판단하여 추가

# %%
# 마스크 이미지 생성
mask_img = np.array( Image.open( './data/stormtrooper_mask.png' ) )
mask_img.shape
# Out:
# (1028, 1190)

# %%
# 워드 생성
wc = WordCloud( max_words=1000, 
                mask=mask_img, 
                stopwords=stopwords,
                margin=10).generate( text )

# %%
# 칼라값 활용
tmp = wc.to_array()
tmp.shape
# Out:
# (1028, 1190, 3)

# %%
wc.words_
'''
{'Luke': 1.0,
 'Han': 0.45904761904761904,
 'DEATH STAR': 0.4266666666666667,
 'THREEPIO': 0.37523809523809526,
 ...
'''

# %%
import random
def color_func( word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl(178, 235%%, %d%%)' % random.randint( 80, 100 )

# %%
# 시각화
plt.figure(figsize=(12,12))
# recolor => 색상을 재구성
plt.imshow( wc.recolor( color_func=color_func, random_state=3 ), 
            interpolation='bilinear' )
plt.axis('off')
plt.show()

# %% [markdown]
# ### KoNLPy를 이용한 처리
# - 기본으로 제공하는 내장 법안을 기준으로 분석
# - 법률 문서 분석

# %%
import nltk

# %%
from konlpy.corpus import kobill

# %%
kobill.fileids()
# Out:
# ['1809890.txt',
#  '1809891.txt',
#  '1809892.txt',
#  '1809893.txt',
#  '1809894.txt',
#  '1809895.txt',
#  '1809896.txt',
#  '1809897.txt',
#  '1809898.txt',
#  '1809899.txt']

# %%
kobill.fileids()[-1]
# Out:
# '1809899.txt'

# %%
doc_ko = kobill.open( kobill.fileids()[5]).read()

# %%
doc_ko[:100], len(doc_ko)
# Out:
# ('하도급거래 공정화에 관한 법률 일부개정법률안\n\n(유선호의원 대표발의 )\n\n 의 안\n 번 호\n\n9895\n\n발의연월일 : 2010.  11.  15.\n\n발  의  자 : 유선호․강기갑',
#  1857)

# %%
from konlpy.tag import Okt
t = Okt()

# %%
# 명사분석
tokens_ko = t.nouns( doc_ko )
tokens_ko[:10], len( tokens_ko )
# Out:
# (['하도급', '거래', '정화', '관', '법률', '일부', '개정', '법률', '안', '유선호'], 368)

# %%
# 분석의 제목  설정
ko = nltk.Text( tokens_ko, name='하도급거래 공정화에 관한 법률 일부개정법률안' )

# %%
len(ko.tokens), len( set(ko.tokens) )
# Out:
# (368, 160)

# %%
# 시긱화
plt.figure(figsize=(12,6))
# 상위 30개만 노출, 빈도수를 표현
ko.plot( 30 )
plt.show()

# %%
# 임의로 stopword를 설정
#stop_words = []

# 한단어는 제거시켜라
ko  = list( filter( lambda x: len(x)>1, ko) )
# 실제 의미를 가진 한글자도 같이 제거가 되므로, 조심

# %%
# 필터 조건은 상황에 맞게 구성하여 배제
# 상황이 더 복잡하면 => 정규식으로 이동
stop_words = [ '.','(',')','%','-','의','을','다','만','로','제','호','및','이','항' ]
def myFileter( x ):
    if len(x)>1: # 한글자 제거
        return True
    else:
        if x not in stop_words: # 배제 단어에 없으면 회생
            return True
        else: # 배제 단어에 포함되어 있으면 제거
            return False

def myFileter2( x ):
    # 한글자 이상이거나, 배제 단어에 없으면 포함
    return  (len(x)>1 or x not in stop_words)

# %%
ko  = list( filter( myFileter, ko) )

# %%
len(ko), ko
# Out:
# (226,
#  ['하도급',
#   '거래',
#   '정화',
#   '법률',
#   '일부',
#   '개정',
#   '법률',
#   '유선호',
#   '의원',
#   '대표',
#   '발의',
#   '발의',
#   '연월일',
#   '유선호',
#   '강기갑',
#   '김효석',
#   '조승수',
#   '최문순',
#   '조영택',
#   '문학진',
#   '백재현',
#   '송민순',
#   '박은수',
#   '정동영',
#   '김춘진',
#   '김재윤',
#   '우윤근',
#   '이성남',
#   '이종걸',
#   '의원',
#   '제안',
#   '이유',
#   '내용',
#   '수급',
#   '사업자',
#   '사이',
#   '하도급',
#   '거래',
#   '외형',
#   '계약',
#   '교섭',
#   '절대',
#   '우위',
#   '사업자',
#   '불공정',
#   '행위',
#   '가능성',
#   '상존',
#   '또한',
#   '수급',
#   '사업자',
#   '사업자',
#   '부당행위',
#   '손해',
#   '경우',
#   '입증',
#   '부담',
#   '때문',
#   '민사소송',
#   '피해',
#   '제도',
#   '실정',
#   '서면',
#   '계약',
#   '경우',
#   '벌금',
#   '손해배상',
#   '입증책임',
#   '사업자',
#   '전환',
#   '법원',
#   '추정',
#   '손해',
#   '인정',
#   '수급',
#   '사업자',
#   '소송',
#   '용의',
#   '진행',
#   '대칭',
#   '교섭',
#   '정보',
#   '차이',
#   '보완',
#   '하도급',
#   '거래',
#   '질서',
#   '유지',
#   '발전',
#   '것임',
#   '신설',
#   '법률',
#   '하도급',
#   '거래',
#   '정화',
#   '법률',
#   '일부',
#   '개정',
#   '법률',
#   '하도급',
#   '거래',
#   '정화',
#   '법률',
#   '일부',
#   '다음',
#   '개정',
#   '항제',
#   '각각',
#   '호로',
#   '다음',
#   '신설',
#   '위반',
#   '각각',
#   '다음',
#   '신설',
#   '손해배상',
#   '책임',
#   '사업자',
#   '위반',
#   '손해',
#   '자가',
#   '경우',
#   '자의',
#   '손해',
#   '대하',
#   '해당',
#   '사업자',
#   '배상',
#   '책임',
#   '다만',
#   '해당',
#   '사업자',
#   '고의',
#   '과실',
#   '입증',
#   '경우',
#   '손해',
#   '인정',
#   '법원',
#   '위반',
#   '행위',
#   '손해',
#   '발생',
#   '사실',
#   '인정',
#   '손해',
#   '구체',
#   '금액',
#   '산정',
#   '곤란',
#   '경우',
#   '변론',
#   '취지',
#   '증거조사',
#   '결과',
#   '고려',
#   '상당',
#   '손해',
#   '인정',
#   '시행일',
#   '공포',
#   '시행',
#   '용례',
#   '항제',
#   '개정',
#   '규정',
#   '시행',
#   '최초',
#   '체결',
#   '하도급',
#   '계약',
#   '적용',
#   '구조',
#   '문대비',
#   '벌칙',
#   '벌칙',
#   '현행',
#   '다음',
#   '호의',
#   '하나',
#   '해당',
#   '하의',
#   '벌금',
#   '현행',
#   '위반',
#   '현행',
#   '손해배상',
#   '책임',
#   '사업자',
#   '위반',
#   '손해',
#   '자가',
#   '경우',
#   '자의',
#   '손해',
#   '대하',
#   '해당',
#   '원사',
#   '업자',
#   '배상',
#   '책임',
#   '다만',
#   '해당',
#   '사업자',
#   '고의',
#   '입증',
#   '경우',
#   '손해',
#   '인정',
#   '법원',
#   '위반',
#   '행위',
#   '발생',
#   '사실',
#   '인정',
#   '손해',
#   '구체',
#   '금액',
#   '경우',
#   '변론',
#   '취지',
#   '증거조사',
#   '결과',
#   '고려',
#   '손해',
#   '인정'])

# %%
stop_words = [ '.','(',')','%','-','의','을','다','만','로','제','호','및','이','항' ]
ko = [ each_word  for each_word in ko if each_word not in stop_words  ] 
ko
# Out:
# ['하도급',
#  '거래',
#  '정화',
#  '관',
#  '법률',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '유선호',
#  '의원',
#  '대표',
#  '발의',
#  '안',
#  '번',
#  '발의',
#  '연월일',
#  '발',
#  '자',
#  '유선호',
#  '강기갑',
#  '김효석',
#  '조승수',
#  '최문순',
#  '조영택',
#  '문학진',
#  '백재현',
#  '송민순',
#  '박은수',
#  '정동영',
#  '김춘진',
#  '김재윤',
#  '우윤근',
#  '이성남',
#  '이종걸',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '내용',
#  '원',
#  '수급',
#  '사업자',
#  '사이',
#  '하도급',
#  '거래',
#  '외형',
#  '계약',
#  '체',
#  '결',
#  '교섭',
#  '절대',
#  '우위',
#  '사업자',
#  '불공정',
#  '행위',
#  '가능성',
#  '상존',
#  '또한',
#  '수급',
#  '사업자',
#  '사업자',
#  '부당행위',
#  '손해',
#  '경우',
#  '입증',
#  '부담',
#  '때문',
#  '민사소송',
#  '피해',
#  '제도',
#  '실정',
#  '임',
#  '서면',
#  '계약',
#  '경우',
#  '벌금',
#  '처',
#  '손해배상',
#  '입증책임',
#  '사업자',
#  '전환',
#  '법원',
#  '추정',
#  '손해',
#  '액',
#  '인정',
#  '수',
#  '수급',
#  '사업자',
#  '소송',
#  '용의',
#  '진행',
#  '수',
#  '함',
#  '비',
#  '대칭',
#  '교섭',
#  '정보',
#  '차이',
#  '를',
#  '보완',
#  '하도급',
#  '거래',
#  '질서',
#  '유지',
#  '발전',
#  '것임',
#  '안',
#  '신설',
#  '법률',
#  '하도급',
#  '거래',
#  '정화',
#  '관',
#  '법률',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '하도급',
#  '거래',
#  '정화',
#  '관',
#  '법률',
#  '일부',
#  '다음',
#  '개정',
#  '항제',
#  '각각',
#  '호로',
#  '다음',
#  '신설',
#  '위반',
#  '자',
#  '각각',
#  '다음',
#  '신설',
#  '손해배상',
#  '책임',
#  '사업자',
#  '법',
#  '위반',
#  '함',
#  '손해',
#  '자가',
#  '경우',
#  '그',
#  '자의',
#  '손해',
#  '대하',
#  '해당',
#  '사업자',
#  '배상',
#  '책임',
#  '다만',
#  '해당',
#  '사업자',
#  '고의',
#  '과실',
#  '음',
#  '입증',
#  '경우',
#  '손해',
#  '액',
#  '인정',
#  '법원',
#  '법',
#  '위반',
#  '행위',
#  '손해',
#  '발생',
#  '사실',
#  '인정',
#  '손해',
#  '액',
#  '구체',
#  '금액',
#  '산정',
#  '곤란',
#  '경우',
#  '변론',
#  '취지',
#  '증거조사',
#  '결과',
#  '고려',
#  '그',
#  '상당',
#  '손해',
#  '액',
#  '인정',
#  '수',
#  '부',
#  '칙',
#  '시행일',
#  '법',
#  '공포',
#  '날',
#  '시행',
#  '적',
#  '용례',
#  '항제',
#  '개정',
#  '규정',
#  '법',
#  '시행',
#  '후',
#  '최초',
#  '체결',
#  '하도급',
#  '계약',
#  '적용',
#  '신',
#  '구조',
#  '문대비',
#  '표',
#  '현',
#  '행',
#  '개',
#  '정',
#  '안',
#  '벌칙',
#  '생',
#  '략',
#  '벌칙',
#  '현행',
#  '다음',
#  '각',
#  '호의',
#  '하나',
#  '해당',
#  '하의',
#  '벌금',
#  '처',
#  '신',
#  '설',
#  '생',
#  '략',
#  '현행',
#  '위반',
#  '자',
#  '생',
#  '략',
#  '신',
#  '설',
#  '현행',
#  '손해배상',
#  '책임',
#  '사업자',
#  '법',
#  '위반',
#  '함',
#  '손해',
#  '자가',
#  '경우',
#  '그',
#  '자의',
#  '손해',
#  '대하',
#  '해당',
#  '원사',
#  '업자',
#  '배상',
#  '책임',
#  '다만',
#  '해당',
#  '사업자',
#  '고의',
#  '과',
#  '실',
#  '음',
#  '입증',
#  '경우',
#  '신',
#  '설',
#  '손해',
#  '액',
#  '인정',
#  '법원',
#  '법',
#  '위반',
#  '행위',
#  '손',
#  '해',
#  '발생',
#  '사실',
#  '인정',
#  '손해',
#  '액',
#  '구체',
#  '금액',
#  '산',
#  '정',
#  '경우',
#  '변론',
#  '취지',
#  '증거조사',
#  '결과',
#  '고려',
#  '그',
#  '손해',
#  '액',
#  '인정',
#  '수']

# %%
ko = nltk.Text( ko, name='하도급거래 공정화에 관한 법률 일부개정법률안' )
plt.figure(figsize=(12,6))
ko.plot( 30 )
plt.show()
